# %%
import numpy as np
import matplotlib.pyplot as plt

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y,yp):
    """
    請完成這個 Function 後往下執行
    """

    mse = MSE = sum((y-yp)**2)/len(y)
    return mse
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()


y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()


MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 207.689
# The Mean absolute error is 11.395

# %%
***作業二
1. 你選的這組資料為何重要
Ans: 我選擇的資料是 Google-Landmarks Dataset. 裡面包括大量從網路上得到的世界地標與各地景象. 如果我們曾經去過那個地方, 我們能夠看到圖就說出是那裏.
但是如果我們對任意影像裡的人事物所在地感興趣, 我們希望能有一個資料集來標註這些圖像的地理位置.
2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
Ans: 由於這份資料集提供每張影像的URL及一組對應的ID, 資料應該是爬取網路上大量公開的圖像得到.
3. 蒐集而來的資料型態為何
Ans: 資料型態為每張影像的URL及一組對應的ID,並且對應一組GPS(全球定位系統)座標, 格式以.csv檔案儲存.
4. 這組資料想解決的問題如何評估
Ans: 這組資料想解決的問題是為大量的圖像地標資料提供標註的資料集(annotated datasets). 
評估方法是對每一圖像都有與預測對應的指標, 例如mean Average Precision (mAP). 這一指標用來比較不同方法檢索影像的評分. 

***作業三
1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
Ans: 對於每位司機, Ni是某月份第i次出車的乘客數量, Li是此次出車的里程.假設這月共出車m次, 
則本月績效 Monthly Metric = (Ni*Li^2) sum over i=1:m
我的假設是車隊每輛車都是電動車, 停車(減速)與發車(加速)都會消耗較多電力,而長途定速較為省電. 
同時我也鼓勵與更多乘客的交流(知名度), 因此業績考慮單次出車里程的平方且對人數加權.
2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
Ans: 對於每次出車, 不僅記錄車資也記錄乘客人數來計算業績.
3. 蒐集而來的資料型態為何
Ans: 資料型態為每次出車為一個列(row), 第一欄紀錄第幾次出車, 第二欄紀錄每次出車的乘客量, 最後一欄紀錄每次出車的里程.原則上是一個Nx4的矩陣.
(N為當月出車次數)
4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
Ans: 我要回答的問題是,假設每位司機一整年載客的總收入是Y,我能不能藉由我定義的每月績效一整年的總和,來預測每年度最大的Y出現在哪位司機?
如果可以, 我是不是可以之後建議司機, 
當接到多通叫車通知的時候以人數*里程^2當作是排序依據(蒐集資料的方式舉例在叫車的時候詢問乘客人數,上車地點與目的地), 來最大化車隊的營運收益.
# Out:
#   File "<ipython-input-2-e95f1c81e2eb>", line 1
#     ***作業二
#      ^
# SyntaxError: invalid syntax
